# %% [markdown]
# ## **Fraudulent Claim Detection**

# %% [markdown]
# ## Problem Statement
# Global Insure, a leading insurance company, processes thousands of claims annually. However, a significant percentage of these claims turn out to be fraudulent, resulting in considerable financial losses. The company’s current process for identifying fraudulent claims involves manual inspections, which is time-consuming and inefficient. Fraudulent claims are often detected too late in the process, after the company has already paid out significant amounts. Global Insure wants to improve its fraud detection process using data-driven insights to classify claims as fraudulent or legitimate early in the approval process. This would minimise financial losses and optimise the overall claims handling process.
#
# ## Business Objective
# Global Insure wants to build a model to classify insurance claims as either fraudulent or legitimate based on historical claim details and customer profiles. By using features like claim amounts, customer profiles and claim types, the company aims to predict which claims are likely to be fraudulent before they are approved.
#
#
# Based on this assignment, you have to answer the following questions:<br>
#
# ● How can we analyse historical claim data to detect patterns that indicate fraudulent claims?<br>
# ● Which features are most predictive of fraudulent behaviour?<br>
# ● Can we predict the likelihood of fraud for an incoming claim, based on past data?<br>
# ● What insights can be drawn from the model that can help in improving the fraud detection process?<br>

# %% [markdown]
# ## Assignment Tasks
# You need to perform the following steps for successfully completing this assignment:
# 1. Data Preparation
# 2. Data Cleaning
# 3. Train Validation Split 70-30
# 4. EDA on Training Data
# 5. EDA on Validation Data (optional)
# 6. Feature Engineering
# 7. Model Building
# 8. Predicting and Model Evaluation

# %% [markdown]
# ## Data Dictionary
# The insurance claims data has 40 Columns and 1000 Rows. Following data dictionary provides the description for each column present in dataset:<br>
#
# <table>
#   <thead>
#     <tr>
#       <th>Column Name</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>months_as_customer</td>
#       <td>Represents the duration in months that a customer has been associated with the insurance company.</td>
#     </tr>
#     <tr>
#       <td>age</td>
#       <td>Represents the age of the insured person.</td>
#     </tr>
#     <tr>
#       <td>policy_number</td>
#       <td>Represents a unique identifier for each insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_bind_date</td>
#       <td>Represents the date when the insurance policy was initiated.</td>
#     </tr>
#     <tr>
#       <td>policy_state</td>
#       <td>Represents the state where the insurance policy is applicable.</td>
#     </tr>
#     <tr>
#       <td>policy_csl</td>
#       <td>Represents the combined single limit for the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_deductable</td>
#       <td>Represents the amount that the insured person needs to pay before the insurance coverage kicks in.</td>
#     </tr>
#     <tr>
#       <td>policy_annual_premium</td>
#       <td>Represents the yearly cost of the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>umbrella_limit</td>
#       <td>Represents an additional layer of liability coverage provided beyond the limits of the primary insurance policy.</td>
#     </tr>
#     <tr>
#       <td>insured_zip</td>
#       <td>Represents the zip code of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_sex</td>
#       <td>Represents the gender of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_education_level</td>
#       <td>Represents the highest educational qualification of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_occupation</td>
#       <td>Represents the profession or job of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_hobbies</td>
#       <td>Represents the hobbies or leisure activities of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_relationship</td>
#       <td>Represents the relationship of the insured person to the policyholder.</td>
#     </tr>
#     <tr>
#       <td>capital-gains</td>
#       <td>Represents the profit earned from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>capital-loss</td>
#       <td>Represents the loss incurred from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>incident_date</td>
#       <td>Represents the date when the incident or accident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_type</td>
#       <td>Represents the category or type of incident that led to the claim.</td>
#     </tr>
#     <tr>
#       <td>collision_type</td>
#       <td>Represents the type of collision that occurred in an accident.</td>
#     </tr>
#     <tr>
#       <td>incident_severity</td>
#       <td>Represents the extent of damage or injury caused by the incident.</td>
#     </tr>
#     <tr>
#       <td>authorities_contacted</td>
#       <td>Represents the authorities or agencies that were contacted after the incident.</td>
#     </tr>
#     <tr>
#       <td>incident_state</td>
#       <td>Represents the state where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_city</td>
#       <td>Represents the city where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_location</td>
#       <td>Represents the specific location or address where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_hour_of_the_day</td>
#       <td>Represents the hour of the day when the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>number_of_vehicles_involved</td>
#       <td>Represents the total number of vehicles involved in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_damage</td>
#       <td>Represents whether there was any damage to property in the incident.</td>
#     </tr>
#     <tr>
#       <td>bodily_injuries</td>
#       <td>Represents the number of bodily injuries resulting from the incident.</td>
#     </tr>
#     <tr>
#       <td>witnesses</td>
#       <td>Represents the number of witnesses present at the scene of the incident.</td>
#     </tr>
#     <tr>
#       <td>police_report_available</td>
#       <td>Represents whether a police report is available for the incident.</td>
#     </tr>
#     <tr>
#       <td>total_claim_amount</td>
#       <td>Represents the total amount claimed by the insured person for the incident.</td>
#     </tr>
#     <tr>
#       <td>injury_claim</td>
#       <td>Represents the amount claimed for injuries sustained in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_claim</td>
#       <td>Represents the amount claimed for property damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>vehicle_claim</td>
#       <td>Represents the amount claimed for vehicle damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>auto_make</td>
#       <td>Represents the manufacturer of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_model</td>
#       <td>Represents the specific model of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_year</td>
#       <td>Represents the year of manufacture of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>fraud_reported</td>
#       <td>Represents whether the claim was reported as fraudulent or not.</td>
#     </tr>
#     <tr>
#       <td>_c39</td>
#       <td>Represents an unknown or unspecified variable.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **1. Data Preparation**
# In this step, read the dataset provided in CSV format and look at basic statistics of the data, including preview of data, dimension of data, column descriptions and data types.

# %% [markdown]
# ### **1.0 Import Libraries**

# %%
# Supress unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### **1.1 Load the Data**

# %%
# Load the dataset
df = pd.read_csv(r'C:\Users\hp\Downloads\insurance_claims.csv')

# %%
# Check at the first few entries
print(df.head())
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES              71610         6510
# 1       468176  ...                       ?               5070          780
# 2       430632  ...                      NO              34650         7700
# 3       608117  ...                      NO              63400         6340
# 4       610706  ...                      NO               6500         1300
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0          13020         52080       Saab         92x      2004
# 1            780          3510   Mercedes        E400      2007
# 2           3850         23100      Dodge         RAM      2007
# 3           6340         50720  Chevrolet       Tahoe      2014
# 4            650          4550     Accura         RSX      2009
#
#   fraud_reported _c39
# 0              Y  NaN
# 1              Y  NaN
# 2              N  NaN
# 3              Y  NaN
# 4              N  NaN
#
# [5 rows x 40 columns]

# %%
# Inspect the shape of the dataset
print(df.shape)
# Out:
# (1000, 40)

# %%
# Inspect the features in the dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
#  13  insured_hobbies              1000 non-null   object
#  14  insured_relationship         1000 non-null   object
#  15  capital-gains                1000 non-null   int64
#  16  capital-loss                 1000 non-null   int64
#  17  incident_date                1000 non-null   object
#  18  incident_type                1000 non-null   object
#  19  collision_type               1000 non-null   object
#  20  incident_severity            1000 non-null   object
#  21  authorities_contacted        909 non-null    object
#  22  incident_state               1000 non-null   object
#  23  incident_city                1000 non-null   object
#  24  incident_location            1000 non-null   object
#  25  incident_hour_of_the_day     1000 non-null   int64
#  26  number_of_vehicles_involved  1000 non-null   int64
#  27  property_damage              1000 non-null   object
#  28  bodily_injuries              1000 non-null   int64
#  29  witnesses                    1000 non-null   int64
#  30  police_report_available      1000 non-null   object
#  31  total_claim_amount           1000 non-null   int64
#  32  injury_claim                 1000 non-null   int64
#  33  property_claim               1000 non-null   int64
#  34  vehicle_claim                1000 non-null   int64
#  35  auto_make                    1000 non-null   object
#  36  auto_model                   1000 non-null   object
#  37  auto_year                    1000 non-null   int64
#  38  fraud_reported               1000 non-null   object
#  39  _c39                         0 non-null      float64
# dtypes: float64(2), int64(17), object(21)
# memory usage: 312.6+ KB
# None

# %% [markdown]
# ## **2. Data Cleaning** <font color = red>[10 marks]</font>

# %% [markdown]
# ### **2.1 Handle null values** <font color = red>[2 marks]</font>

# %% [markdown]
# #### **2.1.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[1 Mark]</font>

# %%
# Check the number of missing values in each column
print(df.isnull().sum())
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                   0
# bodily_injuries                   0
# witnesses                         0
# police_report_available           0
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# auto_make                         0
# auto_model                        0
# auto_year                         0
# fraud_reported                    0
# _c39                           1000
# dtype: int64

# %% [markdown]
# #### **2.1.2** Handle rows containing null values <font color="red">[1 Mark]</font>

# %%
df = df.dropna(axis=1, how='all')

# %%
print(df.columns)
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
# Handle the rows containing null values
df_cleaned = df.dropna()

# %%
print(df.columns)
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %% [markdown]
# ### **2.2 Identify and handle redundant values and columns** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **2.2.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[2 Mark]</font>

# %%
# Write code to display all the columns with their unique values and counts and check for redundant values
for col in df.columns:
    print(f"Column: {col}")
    print(df[col].value_counts(dropna=False))  # include NaN values in counts
    print("-" * 40)
# Out:
# Column: months_as_customer
# months_as_customer
# 194    8
# 128    7
# 254    7
# 140    7
# 210    7
#       ..
# 390    1
# 411    1
# 453    1
# 448    1
# 17     1
# Name: count, Length: 391, dtype: int64
# ----------------------------------------
# Column: age
# age
# 43    49
# 39    48
# 41    45
# 34    44
# 38    42
# 30    42
# 31    42
# 37    41
# 33    39
# 40    38
# 32    38
# 29    35
# 46    33
# 42    32
# 35    32
# 36    32
# 44    32
# 28    30
# 26    26
# 45    26
# 48    25
# 47    24
# 27    24
# 57    16
# 25    14
# 55    14
# 49    14
# 53    13
# 50    13
# 24    10
# 54    10
# 61    10
# 51     9
# 60     9
# 58     8
# 56     8
# 23     7
# 21     6
# 59     5
# 62     4
# 52     4
# 64     2
# 63     2
# 19     1
# 20     1
# 22     1
# Name: count, dtype: int64
# ----------------------------------------
# Column: policy_number
# policy_number
# 521585    1
# 687755    1
# 674485    1
# 223404    1
# 991480    1
#          ..
# 563878    1
# 620855    1
# 583169    1
# 337677    1
# 556080    1
# Name: count, Length: 1000, dtype: int64
# ----------------------------------------
# Column: policy_bind_date
# policy_bind_date
# 2006-01-01    3
# 1992-04-28    3
# 1992-08-05    3
# 1991-12-14    2
# 2004-08-09    2
#              ..
# 2014-06-03    1
# 1998-12-12    1
# 1999-02-18    1
# 1997-10-30    1
# 1996-11-11    1
# Name: count, Length: 951, dtype: int64
# ----------------------------------------
# Column: policy_state
# policy_state
# OH    352
# IL    338
# IN    310
# Name: count, dtype: int64
# ----------------------------------------
# Column: policy_csl
# policy_csl
# 250/500     351
# 100/300     349
# 500/1000    300
# Name: count, dtype: int64
# ----------------------------------------
# Column: policy_deductable
# policy_deductable
# 1000    351
# 500     342
# 2000    307
# Name: count, dtype: int64
# ----------------------------------------
# Column: policy_annual_premium
# policy_annual_premium
# 1558.29    2
# 1215.36    2
# 1362.87    2
# 1073.83    2
# 1389.13    2
#           ..
# 1085.03    1
# 1437.33    1
# 988.29     1
# 1238.89    1
# 766.19     1
# Name: count, Length: 991, dtype: int64
# ----------------------------------------
# Column: umbrella_limit
# umbrella_limit
#  0           798
#  6000000      57
#  5000000      46
#  4000000      39
#  7000000      29
#  3000000      12
#  8000000       8
#  9000000       5
#  2000000       3
#  10000000      2
# -1000000       1
# Name: count, dtype: int64
# ----------------------------------------
# Column: insured_zip
# insured_zip
# 477695    2
# 469429    2
# 446895    2
# 431202    2
# 456602    2
#          ..
# 476303    1
# 450339    1
# 476502    1
# 600561    1
# 612260    1
# Name: count, Length: 995, dtype: int64
# ----------------------------------------
# Column: insured_sex
# insured_sex
# FEMALE    537
# MALE      463
# Name: count, dtype: int64
# ----------------------------------------
# Column: insured_education_level
# insured_education_level
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: count, dtype: int64
# ----------------------------------------
# Column: insured_occupation
# insured_occupation
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# sales                76
# exec-managerial      76
# craft-repair         74
# transport-moving     72
# other-service        71
# priv-house-serv      71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: count, dtype: int64
# ----------------------------------------
# Column: insured_hobbies
# insured_hobbies
# reading           64
# exercise          57
# paintball         57
# bungie-jumping    56
# movies            55
# golf              55
# camping           55
# kayaking          54
# yachting          53
# hiking            52
# video-games       50
# skydiving         49
# base-jumping      49
# board-games       48
# polo              47
# chess             46
# dancing           43
# sleeping          41
# cross-fit         35
# basketball        34
# Name: count, dtype: int64
# ----------------------------------------
# Column: insured_relationship
# insured_relationship
# own-child         183
# other-relative    177
# not-in-family     174
# husband           170
# wife              155
# unmarried         141
# Name: count, dtype: int64
# ----------------------------------------
# Column: capital-gains
# capital-gains
# 0        508
# 46300      5
# 51500      4
# 68500      4
# 55600      3
#         ...
# 36700      1
# 54900      1
# 69200      1
# 48800      1
# 50300      1
# Name: count, Length: 338, dtype: int64
# ----------------------------------------
# Column: capital-loss
# capital-loss
#  0        475
# -31700      5
# -53700      5
# -50300      5
# -45300      4
#          ...
# -12100      1
# -17000      1
# -72900      1
# -19700      1
# -82100      1
# Name: count, Length: 354, dtype: int64
# ----------------------------------------
# Column: incident_date
# incident_date
# 2015-02-02    28
# 2015-02-17    26
# 2015-01-07    25
# 2015-01-10    24
# 2015-02-04    24
# 2015-01-24    24
# 2015-01-19    23
# 2015-01-08    22
# 2015-01-13    21
# 2015-01-30    21
# 2015-02-12    20
# 2015-02-22    20
# 2015-01-31    20
# 2015-02-06    20
# 2015-02-21    19
# 2015-01-01    19
# 2015-02-23    19
# 2015-01-12    19
# 2015-01-14    19
# 2015-01-21    19
# 2015-01-03    18
# 2015-02-14    18
# 2015-02-01    18
# 2015-02-28    18
# 2015-01-20    18
# 2015-01-18    18
# 2015-02-25    18
# 2015-01-06    17
# 2015-01-09    17
# 2015-02-08    17
# 2015-02-24    17
# 2015-02-26    17
# 2015-02-13    16
# 2015-02-15    16
# 2015-02-16    16
# 2015-02-05    16
# 2015-01-16    16
# 2015-01-17    15
# 2015-02-18    15
# 2015-01-28    15
# 2015-01-15    15
# 2015-01-22    14
# 2015-02-20    14
# 2015-02-27    14
# 2015-01-23    13
# 2015-02-03    13
# 2015-01-27    13
# 2015-02-09    13
# 2015-01-04    12
# 2015-03-01    12
# 2015-01-26    11
# 2015-01-29    11
# 2015-01-02    11
# 2015-02-19    10
# 2015-02-11    10
# 2015-02-10    10
# 2015-02-07    10
# 2015-01-25    10
# 2015-01-11     9
# 2015-01-05     7
# Name: count, dtype: int64
# ----------------------------------------
# Column: incident_type
# incident_type
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: count, dtype: int64
# ----------------------------------------
# Column: collision_type
# collision_type
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# ?                  178
# Name: count, dtype: int64
# ----------------------------------------
# Column: incident_severity
# incident_severity
# Minor Damage      354
# Total Loss        280
# Major Damage      276
# Trivial Damage     90
# Name: count, dtype: int64
# ----------------------------------------
# Column: authorities_contacted
# authorities_contacted
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# NaN           91
# Name: count, dtype: int64
# ----------------------------------------
# Column: incident_state
# incident_state
# NY    262
# SC    248
# WV    217
# VA    110
# NC    110
# PA     30
# OH     23
# Name: count, dtype: int64
# ----------------------------------------
# Column: incident_city
# incident_city
# Springfield    157
# Arlington      152
# Columbus       149
# Northbend      145
# Hillsdale      141
# Riverwood      134
# Northbrook     122
# Name: count, dtype: int64
# ----------------------------------------
# Column: incident_location
# incident_location
# 9935 4th Drive         1
# 4214 MLK Ridge         1
# 8548 Cherokee Ridge    1
# 2352 MLK Drive         1
# 9734 2nd Ridge         1
#                       ..
# 6770 1st St            1
# 4119 Texas St          1
# 4347 2nd Ridge         1
# 1091 1st Drive         1
# 1416 Cherokee Ridge    1
# Name: count, Length: 1000, dtype: int64
# ----------------------------------------
# Column: incident_hour_of_the_day
# incident_hour_of_the_day
# 17    54
# 3     53
# 0     52
# 23    51
# 16    49
# 13    46
# 10    46
# 4     46
# 6     44
# 9     43
# 14    43
# 21    42
# 18    41
# 12    40
# 19    40
# 7     40
# 15    39
# 22    38
# 8     36
# 20    34
# 5     33
# 2     31
# 11    30
# 1     29
# Name: count, dtype: int64
# ----------------------------------------
# Column: number_of_vehicles_involved
# number_of_vehicles_involved
# 1    581
# 3    358
# 4     31
# 2     30
# Name: count, dtype: int64
# ----------------------------------------
# Column: property_damage
# property_damage
# ?      360
# NO     338
# YES    302
# Name: count, dtype: int64
# ----------------------------------------
# Column: bodily_injuries
# bodily_injuries
# 0    340
# 2    332
# 1    328
# Name: count, dtype: int64
# ----------------------------------------
# Column: witnesses
# witnesses
# 1    258
# 2    250
# 0    249
# 3    243
# Name: count, dtype: int64
# ----------------------------------------
# Column: police_report_available
# police_report_available
# ?      343
# NO     343
# YES    314
# Name: count, dtype: int64
# ----------------------------------------
# Column: total_claim_amount
# total_claim_amount
# 59400    5
# 2640     4
# 70400    4
# 4320     4
# 44200    4
#         ..
# 65250    1
# 87100    1
# 6240     1
# 66600    1
# 67500    1
# Name: count, Length: 763, dtype: int64
# ----------------------------------------
# Column: injury_claim
# injury_claim
# 0        25
# 640       7
# 480       7
# 660       5
# 580       5
#          ..
# 14840     1
# 6580      1
# 11820     1
# 16650     1
# 7500      1
# Name: count, Length: 638, dtype: int64
# ----------------------------------------
# Column: property_claim
# property_claim
# 0        19
# 860       6
# 480       5
# 660       5
# 10000     5
#          ..
# 3590      1
# 6480      1
# 4580      1
# 4920      1
# 7500      1
# Name: count, Length: 626, dtype: int64
# ----------------------------------------
# Column: vehicle_claim
# vehicle_claim
# 5040     7
# 3360     6
# 52080    5
# 4720     5
# 3600     5
#         ..
# 43360    1
# 25130    1
# 38940    1
# 47430    1
# 52500    1
# Name: count, Length: 726, dtype: int64
# ----------------------------------------
# Column: auto_make
# auto_make
# Saab          80
# Dodge         80
# Suburu        80
# Nissan        78
# Chevrolet     76
# Ford          72
# BMW           72
# Toyota        70
# Audi          69
# Accura        68
# Volkswagen    68
# Jeep          67
# Mercedes      65
# Honda         55
# Name: count, dtype: int64
# ----------------------------------------
# Column: auto_model
# auto_model
# RAM               43
# Wrangler          42
# A3                37
# Neon              37
# MDX               36
# Jetta             35
# Passat            33
# A5                32
# Legacy            32
# Pathfinder        31
# Malibu            30
# 92x               28
# Camry             28
# Forrestor         28
# F150              27
# 95                27
# E400              27
# 93                25
# Grand Cherokee    25
# Escape            24
# Tahoe             24
# Maxima            24
# Ultima            23
# X5                23
# Highlander        22
# Civic             22
# Silverado         22
# Fusion            21
# ML350             20
# Impreza           20
# Corolla           20
# TL                20
# CRV               20
# C300              18
# 3 Series          18
# X6                16
# M5                15
# Accord            13
# RSX               12
# Name: count, dtype: int64
# ----------------------------------------
# Column: auto_year
# auto_year
# 1995    56
# 1999    55
# 2005    54
# 2006    53
# 2011    53
# 2007    52
# 2003    51
# 2009    50
# 2010    50
# 2013    49
# 2002    49
# 2015    47
# 1997    46
# 2012    46
# 2008    45
# 2014    44
# 2001    42
# 2000    42
# 1998    40
# 2004    39
# 1996    37
# Name: count, dtype: int64
# ----------------------------------------
# Column: fraud_reported
# fraud_reported
# N    753
# Y    247
# Name: count, dtype: int64
# ----------------------------------------

# %%
redundant_cols = [col for col in df.columns if df[col].nunique(dropna=False) == 1]
print("Redundant columns with only one unique value:")
print(redundant_cols)
# Out:
# Redundant columns with only one unique value:
# []

# %% [markdown]
# #### **2.2.2** Identify and drop any columns that are completely empty <font color="red">[1 Mark]</font>

# %%
# Identify and drop any columns that are completely empty
# done above

# %% [markdown]
# #### **2.2.3** Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values <font color="red">[1 Mark]</font>

# %%
# Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values
# List of features that should have only non-negative values
non_negative_cols = [
    'months_as_customer', 'age', 'policy_annual_premium', 'umbrella_limit',
    'capital-gains', 'capital-loss', 'incident_hour_of_the_day',
    'number_of_vehicles_involved', 'bodily_injuries', 'witnesses',
    'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim'
]

# Drop rows with negative values in these columns
for col in non_negative_cols:
    df = df[df[col] >= 0]

# %%
# print(df.columns)

# %% [markdown]
# #### **2.2.4** Identify and remove columns where a large proportion of the values are unique or near-unique, as these columns are likely to be identifiers or have very limited predictive power <font color="red">[1 Mark]</font>

# %%
# Identify and remove columns that are likely to be identifiers or have very limited predictive power
for col in df.columns:
    unique_vals = df[col].nunique()
    total_vals = len(df)
    if unique_vals / total_vals > 0.95:
        print(f"Likely ID column: {col} ({unique_vals} unique out of {total_vals})")
# Out:
# Likely ID column: policy_number (474 unique out of 474)
# Likely ID column: policy_bind_date (462 unique out of 474)
# Likely ID column: policy_annual_premium (472 unique out of 474)
# Likely ID column: insured_zip (474 unique out of 474)
# Likely ID column: incident_location (474 unique out of 474)

# %%
#Removing the columns
df = df.drop(columns=[
    'policy_number',         # Unique identifier
    'policy_bind_date',      # Likely irrelevant date
    'insured_zip',           # Likely location info
    'incident_location',     # Free text or location info
    'policy_annual_premium'  # Seems like a unique identifier too
])

# %%
# Check the dataset
print(df.columns)
# Out:
# Index(['months_as_customer', 'age', 'policy_state', 'policy_csl',
#        'policy_deductable', 'umbrella_limit', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'property_damage', 'bodily_injuries', 'witnesses',
#        'police_report_available', 'total_claim_amount', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'auto_make', 'auto_model',
#        'auto_year', 'fraud_reported'],
#       dtype='object')

# %% [markdown]
# ### **2.3 Fix Data Types** <font color = red>[3 marks]</font>
# Carefully examine the dataset and identify columns that contain date or time information but are not stored as the appropriate data type. Convert these columns to the correct datetime data type to enable proper analysis and manipulation of temporal information.

# %%
# Fix the data types of the columns with incorrect data types
print(df.dtypes)
# Out:
# months_as_customer              int64
# age                             int64
# policy_state                   object
# policy_csl                     object
# policy_deductable               int64
# umbrella_limit                  int64
# insured_sex                    object
# insured_education_level        object
# insured_occupation             object
# insured_hobbies                object
# insured_relationship           object
# capital-gains                   int64
# capital-loss                    int64
# incident_date                  object
# incident_type                  object
# collision_type                 object
# incident_severity              object
# authorities_contacted          object
# incident_state                 object
# incident_city                  object
# incident_hour_of_the_day        int64
# number_of_vehicles_involved     int64
# property_damage                object
# bodily_injuries                 int64
# witnesses                       int64
# police_report_available        object
# total_claim_amount              int64
# injury_claim                    int64
# property_claim                  int64
# vehicle_claim                   int64
# auto_make                      object
# auto_model                     object
# auto_year                       int64
# fraud_reported                 object
# dtype: object

# %%
df['policy_state'] = df['policy_state'].astype('category')
df['insured_sex'] = df['insured_sex'].astype('category')
df['insured_education_level'] = df['insured_education_level'].astype('category')
df['insured_occupation'] = df['insured_occupation'].astype('category')

# %%
df['incident_date'] = pd.to_datetime(df['incident_date'], errors='coerce')

# %%
df['months_as_customer'] = pd.to_numeric(df['months_as_customer'], errors='coerce')
df['age'] = pd.to_numeric(df['age'], errors='coerce')
df['capital-gains'] = pd.to_numeric(df['capital-gains'], errors='coerce')
df['capital-loss'] = pd.to_numeric(df['capital-loss'], errors='coerce')
df['total_claim_amount'] = pd.to_numeric(df['total_claim_amount'], errors='coerce')

# %%
df['insured_sex'] = df['insured_sex'].astype('category')
df['incident_type'] = df['incident_type'].astype('category')

# %%
df['fraud_reported'] = df['fraud_reported'].map({'Y': 1, 'N': 0})

# %%
# Check the features of the data again
print(df.dtypes)
# Out:
# months_as_customer                      int64
# age                                     int64
# policy_state                         category
# policy_csl                             object
# policy_deductable                       int64
# umbrella_limit                          int64
# insured_sex                          category
# insured_education_level              category
# insured_occupation                   category
# insured_hobbies                        object
# insured_relationship                   object
# capital-gains                           int64
# capital-loss                            int64
# incident_date                  datetime64[ns]
# incident_type                        category
# collision_type                         object
# incident_severity                      object
# authorities_contacted                  object
# incident_state                         object
# incident_city                          object
# incident_hour_of_the_day                int64
# number_of_vehicles_involved             int64
# property_damage                        object
# bodily_injuries                         int64
# witnesses                               int64
# police_report_available                object
# total_claim_amount                      int64
# injury_claim                            int64
# property_claim                          int64
# vehicle_claim                           int64
# auto_make                              object
# auto_model                             object
# auto_year                               int64
# fraud_reported                          int64
# dtype: object

# %% [markdown]
# ## **3. Train-Validation Split** <font color = red>[5 marks]</font>

# %% [markdown]
# ### **3.1 Import required libraries**

# %%
# Import train-test-split
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **3.2 Define feature and target variables** <font color = red>[2 Marks]</font>

# %%
# Put all the feature variables in X
X = df.drop(columns=['fraud_reported'])

# Put the target variable in y
y = df['fraud_reported']

# %%
# print(X.head())  # Preview feature variables
# print(y.head())

# %% [markdown]
# ### **3.3 Split the data** <font color="red">[3 Marks]</font>

# %%
# Split the dataset into 70% train and 30% validation and use stratification on the target variable
X_train, X_val, y_train, y_val = train_test_split(
    X, y,
    test_size=0.3,
    random_state=42,
    stratify=y
)



# Reset index for all train and test sets
X_train = X_train.reset_index(drop=True)
X_val = X_val.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_val = y_val.reset_index(drop=True)

# %%
print("Train set shape:", X_train.shape)
print("Validation set shape:", X_val.shape)
print("Class distribution in y_train:\n", y_train.value_counts(normalize=True))
print("Class distribution in y_val:\n", y_val.value_counts(normalize=True))
# Out:
# Train set shape: (331, 33)
# Validation set shape: (143, 33)
# Class distribution in y_train:
#  fraud_reported
# 0    0.76435
# 1    0.23565
# Name: proportion, dtype: float64
# Class distribution in y_val:
#  fraud_reported
# 0    0.762238
# 1    0.237762
# Name: proportion, dtype: float64

# %%
print(y_train.shape)
# Out:
# (331,)

# %% [markdown]
# ## **4. EDA on training data** <font color = red>[20 marks]</font>

# %% [markdown]
# ### **4.1 Perform univariate analysis** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **4.1.1** Identify and select numerical columns from training data for univariate analysis <font color = "red">[1 Mark]</font>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Select numerical columns
numerical_cols = X_train.select_dtypes(include=['int64', 'float64']).columns
X_numerical = X[numerical_cols]

# %%
# print("Numerical columns:")
# print(numerical_cols.tolist())

# %% [markdown]
# #### **4.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics <font color = "red">[4 Marks]</font>

# %%
# Plot all the numerical columns to understand their distribution
plt.figure(figsize=(16, 12))
sns.set(style="whitegrid")


for i, col in enumerate(X_numerical.columns):
    plt.subplot((len(X_numerical.columns) + 2) // 3, 3, i + 1)
    sns.histplot(X_numerical[col], kde=True, bins=30)
    plt.title(f'Distribution of {col}')
    plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(16, 12))
for i, col in enumerate(X_numerical.columns):
    plt.subplot((len(X_numerical.columns) + 2) // 3, 3, i + 1)
    sns.boxplot(x=X_numerical[col])
    plt.title(f'Boxplot of {col}')
    plt.tight_layout()

plt.show()

# %% [markdown]
# ### **4.2 Perform correlation analysis** <font color="red">[3 Marks]</font>

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns
corr_matrix = X_numerical.corr()

# Plot Heatmap of the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(
    corr_matrix,
    annot=True,        # display correlation coefficients
    fmt=".2f",         # format to 2 decimal places
    cmap="coolwarm",   # color scheme
    square=True,
    linewidths=0.5,
    cbar_kws={"shrink": 0.75}
)

plt.title("Heatmap of Numerical Feature Correlations")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **4.3 Check class balance** <font color="red">[2 Marks]</font>

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances using visualisation for better understanding.

# %%
# Plot a bar chart to check class balance
plt.figure(figsize=(6, 4))
sns.countplot(x=y, palette='pastel')


plt.title("Class Distribution of Fraud Reported")
plt.xlabel("Fraud Reported")
plt.ylabel("Count")


total = len(y)
for p in plt.gca().patches:
    percentage = f'{100 * p.get_height() / total:.1f}%'
    plt.gca().annotate(percentage, (p.get_x() + 0.3, p.get_height() + 5))

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **4.4 Perform bivariate analysis** <font color="red">[10 Marks]</font>

# %% [markdown]
# #### **4.4.1** Target likelihood analysis for categorical variables. <font color="red">[5 Marks]</font>
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features
def plot_target_likelihood(df, cat_column, target_column='fraud_reported'):
    """
    Plots the likelihood of the target variable for each category in a categorical column.

    Args:
    - df: DataFrame
    - cat_column: Categorical feature name (string)
    - target_column: Target column name (default is 'fraud_reported')
    """
    # Create a new DataFrame with probabilities
    likelihood = df.groupby(cat_column)[target_column].value_counts(normalize=True).unstack().fillna(0)

    # Plot
    plt.figure(figsize=(8, 5))
    likelihood.plot(kind='bar', stacked=True, colormap='coolwarm', figsize=(10, 6))

    plt.title(f"Likelihood of {target_column} by {cat_column}")
    plt.ylabel("Proportion")
    plt.xlabel(cat_column)
    plt.xticks(rotation=45)
    plt.legend(title=target_column)
    plt.tight_layout()
    plt.show()

    return likelihood

# %% [markdown]
# #### **4.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome using appropriate visualisation techniques to identify trends and potential interactions. <font color="red">[5 Marks]</font>

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome
def plot_numerical_vs_target(df, numerical_cols, target_col='fraud_reported'):
    """
    Plots boxplots for each numerical feature grouped by the target variable.
    """
    plt.figure(figsize=(16, len(numerical_cols) * 4))

    for i, col in enumerate(numerical_cols):
        plt.subplot(len(numerical_cols), 2, i + 1)
        sns.boxplot(data=df, x=target_col, y=col, palette='Set2')
        plt.title(f"{col} vs {target_col}")
        plt.tight_layout()

    plt.show()


plot_numerical_vs_target(df, X_numerical.columns.tolist())

# %% [markdown]
# ## **5. EDA on validation data** <font color = red>[OPTIONAL]</font>

# %% [markdown]
# ### **5.1 Perform univariate analysis**

# %% [markdown]
# #### **5.1.1** Identify and select numerical columns from training data for univariate analysis.

# %%
# Select numerical columns
numerical_cols2 = X_train.select_dtypes(include=['int64', 'float64']).columns
X_numerical2 = X[numerical_cols2]

# %% [markdown]
# #### **5.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics.

# %%
# Plot all the numerical columns to understand their distribution

# %% [markdown]
# ### **5.2 Perform correlation analysis**

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns

# Plot Heatmap of the correlation matrix

# %% [markdown]
# ### **5.3 Check class balance**

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances. Visualise the distribution for better understanding.

# %%
# Plot a bar chart to check class balance

# %% [markdown]
# ### **5.4 Perform bivariate analysis**

# %% [markdown]
# #### **5.4.1** Target likelihood analysis for categorical variables.
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features

# %% [markdown]
# #### **5.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome. Utilise appropriate visualisation techniques to identify trends and potential interactions.

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome

# %% [markdown]
# ## **6. Feature Engineering** <font color = red>[25 marks]</font>

# %% [markdown]
# ### **6.1 Perform resampling** <font color="red">[3 Marks]</font>

# %% [markdown]
# Handle class imbalance in the training data by applying resampling technique.
#
# Use the **RandomOverSampler** technique to balance the data and handle class imbalance. This method increases the number of samples in the minority class by randomly duplicating them, creating synthetic data points with similar characteristics. This helps prevent the model from being biased toward the majority class and improves its ability to predict the minority class more accurately.
#
# **Note:** You can try other resampling techniques to handle class imbalance

# %%
# Import RandomOverSampler from imblearn library
from imblearn.over_sampling import RandomOverSampler

# Perform resampling on training data
ros = RandomOverSampler(random_state=42)
X_train_resampled, y_train_resampled = ros.fit_resample(X_train, y_train)

# %%
print("Class distribution after resampling:")
print(y_train_resampled.value_counts(normalize=True))
# Out:
# Class distribution after resampling:
# fraud_reported
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %% [markdown]
# ### **6.2 Feature Creation** <font color="red">[4 marks]</font>

# %% [markdown]
# Create new features from existing ones to enhance the model's ability to capture patterns in the data. This may involve deriving features from date/time columns, combining features, or creating interaction terms.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Separate numerical columns
X_numerical = X_train.select_dtypes(include=['float64', 'int64'])
X_val_numerical = X_val.select_dtypes(include=['float64', 'int64'])

# Separate categorical columns
X_categorical = X_train.select_dtypes(include=['object'])
X_val_categorical = X_val.select_dtypes(include=['object'])

# %%
X_encoded = pd.get_dummies(X_categorical, drop_first=True)
X_val_encoded = pd.get_dummies(X_val_categorical, drop_first=True)
X_val_encoded_aligned = X_val_encoded.reindex(columns=X_encoded.columns, fill_value=0)

# %%
X_combined = pd.concat([X_numerical, X_encoded], axis=1)
X_val_combined = pd.concat([X_val_numerical, X_val_encoded_aligned], axis=1)

# %%
correlation_threshold = 0.18
correlation_with_target = X_combined.apply(lambda col: col.corr(y_train))
strong_features = correlation_with_target[abs(correlation_with_target) > correlation_threshold].index.tolist()
print("Strongly correlated features:", strong_features)
# Out:
# Strongly correlated features: ['vehicle_claim', 'insured_hobbies_chess', 'insured_hobbies_cross-fit', 'incident_severity_Minor Damage', 'incident_severity_Trivial Damage']

# %%
X_fe = X_combined[strong_features].copy()
X_val_fe = X_val_combined[strong_features].copy()

# %%
print(X_fe.columns)
print(X_val_fe.columns)
# Out:
# Index(['vehicle_claim', 'insured_hobbies_chess', 'insured_hobbies_cross-fit',
#        'incident_severity_Minor Damage', 'incident_severity_Trivial Damage'],
#       dtype='object')
# Index(['vehicle_claim', 'insured_hobbies_chess', 'insured_hobbies_cross-fit',
#        'incident_severity_Minor Damage', 'incident_severity_Trivial Damage'],
#       dtype='object')

# %%
# Adding engineered features
X_fe['log_vehicle_claim'] = np.log1p(X_fe['vehicle_claim'])
X_val_fe['log_vehicle_claim'] = np.log1p(X_val_fe['vehicle_claim'])


X_fe['is_chess_or_crossfit'] = (
    X_fe['insured_hobbies_chess'] | X_fe['insured_hobbies_cross-fit']
).astype(int)
X_val_fe['is_chess_or_crossfit'] = (
    X_val_fe['insured_hobbies_chess'] | X_val_fe['insured_hobbies_cross-fit']
).astype(int)



X_fe['is_minor_or_trivial'] = (
    X_fe['incident_severity_Minor Damage'] | X_fe['incident_severity_Trivial Damage']
).astype(int)
X_val_fe['is_minor_or_trivial'] = (
    X_val_fe['incident_severity_Minor Damage'] | X_val_fe['incident_severity_Trivial Damage']
).astype(int)


X_fe['high_claim_and_minor'] = (
    (X_fe['vehicle_claim'] > X_fe['vehicle_claim'].median()) &
    (X_fe['is_minor_or_trivial'] == 1)
).astype(int)
X_val_fe['high_claim_and_minor'] = (
    (X_val_fe['vehicle_claim'] > X_val_fe['vehicle_claim'].median()) &
    (X_val_fe['is_minor_or_trivial'] == 1)
).astype(int)


X_fe['chess_crossfit_with_low_damage'] = (
    (X_fe['is_chess_or_crossfit'] == 1) &
    (X_fe['is_minor_or_trivial'] == 1)
).astype(int)
X_val_fe['chess_crossfit_with_low_damage'] = (
    (X_val_fe['is_chess_or_crossfit'] == 1) &
    (X_val_fe['is_minor_or_trivial'] == 1)
).astype(int)

# %%
print(X_fe.columns)
print(X_val_fe.columns)
# Out:
# Index(['vehicle_claim', 'insured_hobbies_chess', 'insured_hobbies_cross-fit',
#        'incident_severity_Minor Damage', 'incident_severity_Trivial Damage',
#        'log_vehicle_claim', 'is_chess_or_crossfit', 'is_minor_or_trivial',
#        'high_claim_and_minor', 'chess_crossfit_with_low_damage'],
#       dtype='object')
# Index(['vehicle_claim', 'insured_hobbies_chess', 'insured_hobbies_cross-fit',
#        'incident_severity_Minor Damage', 'incident_severity_Trivial Damage',
#        'log_vehicle_claim', 'is_chess_or_crossfit', 'is_minor_or_trivial',
#        'high_claim_and_minor', 'chess_crossfit_with_low_damage'],
#       dtype='object')

# %% [markdown]
# ### **6.3 Handle redundant columns** <font color="red">[3 marks]</font>

# %% [markdown]
# Analyse the data to identify features that may be redundant or contribute minimal information toward predicting the target variable and drop them.
#
# - You can consider features that exhibit high correlation with other variables, which you may have observed during the EDA phase.
# - Features that don't strongly influence the prediction, which you may have observed during the EDA phase.
# - Categorical columns with low value counts for some levels can be remapped to reduce number of unique levels, and features with very high counts for just one level may be removed, as they resemble unique identifier columns and do not provide substantial predictive value.
# - Additionally, eliminate any columns from which the necessary features have already been extracted in the preceding step.

# %%
# Drop redundant columns from training and validation data

redundancy_corr_matrix = X_fe.corr()

# Plot heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(redundancy_corr_matrix, cmap='coolwarm', annot=True, fmt=".2f", vmin=-1, vmax=1)
plt.title("Redundancy Check: Feature Correlation Heatmap")
plt.show()

# %%
redundant_pairs = []
redundancy_threshold = 0.85

for i in range(len(redundancy_corr_matrix.columns)):
    for j in range(i):
        corr = redundancy_corr_matrix.iloc[i, j]
        if abs(corr) > redundancy_threshold:
            f1 = redundancy_corr_matrix.columns[i]
            f2 = redundancy_corr_matrix.columns[j]
            redundant_pairs.append((f1, f2, corr))

print("Highly correlated feature pairs:")
for f1, f2, corr in redundant_pairs:
    print(f"{f1} and {f2}: correlation = {corr:.2f}")
# Out:
# Highly correlated feature pairs:
# log_vehicle_claim and vehicle_claim: correlation = 0.94

# %%
redundant_columns_to_drop = [
    'vehicle_claim',
]

X_fe_cleaned = X_fe.drop(columns=redundant_columns_to_drop)
X_val_fe_cleaned = X_val_fe.drop(columns=redundant_columns_to_drop)

# print("Final feature columns after redundancy removal:", X_fe_cleaned.columns.tolist())
print("Shape after cleaning:", X_fe_cleaned.shape)
print("Shape after cleaning validation", X_val_fe_cleaned.shape)
# Out:
# Shape after cleaning: (331, 9)
# Shape after cleaning validation (143, 9)

# %%
# Check the data
print("Columns in X_fe_cleaned:\n", X_fe_cleaned.columns.tolist())
print("Columns in X_val_fe_cleaned:\n", X_val_fe_cleaned.columns.tolist())
# Out:
# Columns in X_fe_cleaned:
#  ['insured_hobbies_chess', 'insured_hobbies_cross-fit', 'incident_severity_Minor Damage', 'incident_severity_Trivial Damage', 'log_vehicle_claim', 'is_chess_or_crossfit', 'is_minor_or_trivial', 'high_claim_and_minor', 'chess_crossfit_with_low_damage']
# Columns in X_val_fe_cleaned:
#  ['insured_hobbies_chess', 'insured_hobbies_cross-fit', 'incident_severity_Minor Damage', 'incident_severity_Trivial Damage', 'log_vehicle_claim', 'is_chess_or_crossfit', 'is_minor_or_trivial', 'high_claim_and_minor', 'chess_crossfit_with_low_damage']

# %% [markdown]
# ### **6.4 Combine values in Categorical Columns** <font color="red">[6 Marks]</font>
# During the EDA process, categorical columns with multiple unique values may be identified. To enhance model performance, it is essential to refine these categorical features by grouping values that have low frequency or provide limited predictive information.
#
# Combine categories that occur infrequently or exhibit similar behavior to reduce sparsity and improve model generalisation.

# %%
# Combine categories that have low frequency or provide limited predictive information
low_freq_threshold = 0.05
low_freq_dict = {}


X_categorical_train_combined = X_categorical.copy()
X_categorical_val_combined = X_val_categorical.copy()


for col in X_categorical_train_combined.columns:
    freq = X_categorical_train_combined[col].value_counts(normalize=True)
    low_freq_categories = freq[freq < low_freq_threshold].index
    if not low_freq_categories.empty:
        X_categorical_train_combined[col] =X_categorical_train_combined[col].replace(low_freq_categories, 'Other')
        low_freq_dict[col] = low_freq_categories
        # print(f"Replaced low-frequency categories in {col}: {list(low_freq_categories)}")

for col, low_freq_cats in low_freq_dict.items():
    if col in X_categorical_val_combined.columns:
        X_categorical_val_combined[col] = X_categorical_val_combined[col].replace(low_freq_cats, 'Other')
        # print(f"Validation - Replaced in '{col}': {low_freq_cats}")

# %%
X_encoded_train = pd.get_dummies(X_categorical_train_combined, drop_first=True)
X_encoded_val = pd.get_dummies(X_categorical_val_combined, drop_first=True)

# %%
X_encoded_val = X_encoded_val.reindex(columns=X_encoded_train.columns, fill_value=0)

# %%
# print(X_encoded_val.columns)

# %%
X_fe_final = pd.concat([X_fe_cleaned, X_encoded_train], axis=1)
X_val_fe_final = pd.concat([X_val_fe_cleaned, X_encoded_val], axis=1)
# y = df['fraud_reported']

# %%
# print(X_fe_final.columns)
# print(X_val_fe_final.columns)
print(X_fe_final.shape)
print(X_val_fe_final.shape)
# Out:
# (331, 65)
# (143, 65)

# %%
# X_train, X_validation, y_train, y_validation = train_test_split(
#     X_fe_final, y,
#     test_size=0.3,
#     random_state=42,
#     stratify=y
# )

# %%
# X_train = X_train.reset_index(drop=True)
# X_validation = X_validation.reset_index(drop=True)
# y_train = y_train.reset_index(drop=True)
# y_validation = y_validation.reset_index(drop=True)

# %% [markdown]
# ### **6.5 Dummy variable creation** <font color="red">[6 Marks]</font>
# Transform categorical variables into numerical representations using dummy variables. Ensure consistent encoding between training and validation data.

# %% [markdown]
# #### **6.5.1** Identify categorical columns for dummy variable creation <font color="red">[1 Mark]</font>

# %%
# Identify the categorical columns for creating dummy variables
categorical_cols_train = X_train.select_dtypes(include=['object', 'category']).columns.tolist()
print("Categorical columns in training data:", categorical_cols_train)
# Out:
# Categorical columns in training data: ['policy_state', 'policy_csl', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'police_report_available', 'auto_make', 'auto_model']

# %% [markdown]
# #### **6.5.2** Create dummy variables for categorical columns in training data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in training data
X_train_dummies = pd.get_dummies(X_train, columns=categorical_cols_train, drop_first=True)
print("New shape after encoding:", X_train_dummies.shape)
print("Sample columns:", X_train_dummies.columns.tolist()[:10])
# Out:
# New shape after encoding: (331, 143)
# Sample columns: ['months_as_customer', 'age', 'policy_deductable', 'umbrella_limit', 'capital-gains', 'capital-loss', 'incident_date', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries']

# %% [markdown]
# #### **6.5.3** Create dummy variables for categorical columns in validation data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in validation data
X_val_dummies = pd.get_dummies(X_val, columns=categorical_cols_train, drop_first=True)

X_val_aligned = X_val_dummies.reindex(columns=X_train_dummies.columns, fill_value=0)
print("Validation data shape after alignment:", X_val_aligned.shape)
# Out:
# Validation data shape after alignment: (143, 143)

# %% [markdown]
# #### **6.5.4** Create dummy variable for dependent feature in training and validation data <font color = "red">[1 Mark]</font>

# %%
# Create dummy variable for dependent feature in training data
y_train_dummies = pd.get_dummies(y_train, drop_first=True)
print("Shape of y_train_dummies:", y_train_dummies.shape)

# Create dummy variable for dependent feature in validation data
y_val_dummies = pd.get_dummies(y_val, drop_first=True)
print("Shape of y_val_dummies:", y_val_dummies.shape)
# Out:
# Shape of y_train_dummies: (331, 1)
# Shape of y_val_dummies: (143, 1)

# %% [markdown]
# ### **6.6 Feature scaling** <font color = red>[3 marks]</font>
# Scale numerical features to a common range to prevent features with larger values from dominating the model.  Choose a scaling method appropriate for the data and the chosen model. Apply the same scaling to both training and validation data.

# %%
# Import the necessary scaling tool from scikit-learn
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
# Scale the numeric features present in the training data
X_numerical_train = X_fe_final.select_dtypes(include=['float64', 'int64'])
X_numerical_train_scaled = scaler.fit_transform(X_numerical_train)
X_numerical_train_scaled = pd.DataFrame(X_numerical_train_scaled, columns=X_numerical_train.columns)
X_train_scaled = pd.concat([X_numerical_train_scaled, X_encoded_train], axis=1)

# %%
# Scale the numeric features present in the validation data
X_numerical_val = X_val_fe_final.select_dtypes(include=['float64', 'int64'])
X_numerical_val_scaled = scaler.transform(X_numerical_val)
X_numerical_val_scaled = pd.DataFrame(X_numerical_val_scaled, columns=X_numerical_val.columns)
X_val_scaled = pd.concat([X_numerical_val_scaled, X_encoded_val], axis=1)

# %%
print(X_train_scaled.shape)
print(X_val_scaled.shape)
# Out:
# (331, 57)
# (143, 57)

# %%
X_train_scaled = X_train_scaled.apply(lambda x: x.astype(int) if x.dtype == 'bool' else x)
X_val_scaled = X_val_scaled.apply(lambda x: x.astype(int) if x.dtype == 'bool' else x)

# %%
# print(X_train_scaled.dtypes)
# print(X_val_scaled.dtypes)

# %% [markdown]
# ## **7. Model Building** <font color = red>[50 marks]</font>

# %% [markdown]
# In this task, you will be building two machine learning models: Logistic Regression and Random Forest. Each model will go through a structured process to ensure optimal performance. The key steps for each model are outlined below:
#
# **Logistic Regression Model**
# - Feature Selection using RFECV – Identify the most relevant features using Recursive Feature Elimination with Cross-Validation.
# - Model Building and Multicollinearity Assessment – Build the logistic regression model and analyse statistical aspects such as p-values and VIFs to detect multicollinearity.
# - Model Training and Evaluation on Training Data – Fit the model on the training data and assess initial performance.
# - Finding the Optimal Cutoff – Determine the best probability threshold by analysing the sensitivity-specificity tradeoff and precision-recall tradeoff.
# - FInal Prediction and Evaluation on Training Data using the Optimal Cutoff – Generate final predictions using the selected cutoff and evaluate model performance.
#
# **Random Forest Model**
# - Get Feature Importances - Obtain the importance scores for each feature and select the important features to train the model.
# - Model Evaluation on Training Data – Assess performance metrics on the training data.
# - Check Model Overfitting using Cross-Validation – Evaluate generalisation by performing cross-validation.
# - Hyperparameter Tuning using Grid Search – Optimise model performance by fine-tuning hyperparameters.
# - Final Model and Evaluation on Training Data – Train the final model using the best parameters and assess its performance.

# %% [markdown]
# ### **7.1 Feature selection** <font color = red>[4 marks]</font>
# Identify and select the most relevant features for building a logistic regression model using Recursive Feature Elimination with Cross-Validation (RFECV).

# %% [markdown]
# #### **7.1.1** Import necessary libraries <font color="red">[1 Mark]</font>

# %%
# Import necessary libraries
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# #### **7.1.2** Perform feature selection <font color="red">[2 Mark]</font>

# %%
print(f"Shape of X_train_scaled: {X_train_scaled.shape}")
print(f"Shape of y_train: {y_train.shape}")
# Out:
# Shape of X_train_scaled: (331, 57)
# Shape of y_train: (331,)

# %%
# Apply RFECV to identify the most relevant features
model = RandomForestClassifier(n_estimators=100, random_state=42)

selector = RFECV(estimator=model, step=1, cv=5)

selector.fit(X_train_scaled, y_train)
print(f"Optimal number of features: {selector.n_features_}")

selected_features = X_train_scaled.columns[selector.support_].tolist()
print(f"Selected features: {selected_features}")
# Out:
# Optimal number of features: 28
# Selected features: ['log_vehicle_claim', 'policy_csl_250/500', 'policy_csl_500/1000', 'insured_relationship_not-in-family', 'insured_relationship_other-relative', 'insured_relationship_unmarried', 'insured_relationship_wife', 'collision_type_Front Collision', 'collision_type_Rear Collision', 'collision_type_Side Collision', 'incident_severity_Minor Damage', 'incident_severity_Total Loss', 'authorities_contacted_Fire', 'authorities_contacted_Other', 'authorities_contacted_Police', 'incident_state_NY', 'incident_state_SC', 'incident_state_WV', 'incident_city_Columbus', 'incident_city_Northbend', 'incident_city_Riverwood', 'incident_city_Springfield', 'property_damage_NO', 'property_damage_YES', 'police_report_available_NO', 'police_report_available_YES', 'auto_make_Ford', 'auto_make_Mercedes']

# %%
# Display the features ranking by RFECV in a DataFrame
ranking_df = pd.DataFrame({
    'Feature': X_train_scaled.columns,  # Column names (feature names)
    'Ranking': selector.ranking_  # Feature ranking (1 is best)
})


ranking_df = ranking_df.sort_values(by='Ranking')
print(ranking_df)
# Out:
#                                 Feature  Ranking
# 0                     log_vehicle_claim        1
# 23       incident_severity_Minor Damage        1
# 24         incident_severity_Total Loss        1
# 26           authorities_contacted_Fire        1
# 27          authorities_contacted_Other        1
# 29                    incident_state_NY        1
# 31                    incident_state_SC        1
# 33                    incident_state_WV        1
# 34               incident_city_Columbus        1
# 36              incident_city_Northbend        1
# 38              incident_city_Riverwood        1
# 39            incident_city_Springfield        1
# 40                   property_damage_NO        1
# 41                  property_damage_YES        1
# 42           police_report_available_NO        1
# 43          police_report_available_YES        1
# 47                       auto_make_Ford        1
# 50                   auto_make_Mercedes        1
# 22        collision_type_Side Collision        1
# 21        collision_type_Rear Collision        1
# 28         authorities_contacted_Police        1
# 19            insured_relationship_wife        1
# 18       insured_relationship_unmarried        1
# 16  insured_relationship_other-relative        1
# 15   insured_relationship_not-in-family        1
# 1                    policy_csl_250/500        1
# 2                   policy_csl_500/1000        1
# 20       collision_type_Front Collision        1
# 32                    incident_state_VA        2
# 25     incident_severity_Trivial Damage        3
# 17       insured_relationship_own-child        4
# 37             incident_city_Northbrook        5
# 3          insured_hobbies_base-jumping        6
# 53                       auto_make_Saab        7
# 35              incident_city_Hillsdale        8
# 30                 incident_state_Other        9
# 46                      auto_make_Dodge       10
# 56                 auto_make_Volkswagen       11
# 54                     auto_make_Suburu       12
# 44                        auto_make_BMW       13
# 48                      auto_make_Honda       14
# 10            insured_hobbies_paintball       15
# 5               insured_hobbies_camping       16
# 45                  auto_make_Chevrolet       17
# 12              insured_hobbies_reading       18
# 14             insured_hobbies_yachting       19
# 4        insured_hobbies_bungie-jumping       20
# 51                     auto_make_Nissan       21
# 6              insured_hobbies_exercise       22
# 8                insured_hobbies_hiking       23
# 13             insured_hobbies_sleeping       24
# 49                       auto_make_Jeep       25
# 55                     auto_make_Toyota       26
# 11                 insured_hobbies_polo       27
# 52                      auto_make_Other       28
# 7                  insured_hobbies_golf       29
# 9                insured_hobbies_movies       30

# %% [markdown]
# #### **7.1.2** Retain the selected features <font color="red">[1 Mark]</font>

# %%
# Put columns selected by RFECV into variable 'col'
col = X_train_scaled.columns[selector.support_].tolist()

# %% [markdown]
# ### **7.2 Build Logistic Regression Model** <font color = red>[12 marks]</font>
# After selecting the optimal features using RFECV, utilise these features to build a logistic regression model with Statsmodels. This approach enables a detailed statistical analysis of the model, including the assessment of p-values and Variance Inflation Factors (VIFs). Evaluating these metrics is crucial for detecting multicollinearity and ensuring that the selected predictors are not highly correlated.

# %% [markdown]
# #### **7.2.1** Select relevant features and add constant in training data <font color="red">[1 Mark]</font>

# %%
# Select only the columns selected by RFECV
X_train_selected = X_train_scaled[col]

# %%
print(X_train_selected.dtypes)
print(y_train.dtypes)
# Out:
# log_vehicle_claim                      float64
# policy_csl_250/500                       int32
# policy_csl_500/1000                      int32
# insured_relationship_not-in-family       int32
# insured_relationship_other-relative      int32
# insured_relationship_unmarried           int32
# insured_relationship_wife                int32
# collision_type_Front Collision           int32
# collision_type_Rear Collision            int32
# collision_type_Side Collision            int32
# incident_severity_Minor Damage           int32
# incident_severity_Total Loss             int32
# authorities_contacted_Fire               int32
# authorities_contacted_Other              int32
# authorities_contacted_Police             int32
# incident_state_NY                        int32
# incident_state_SC                        int32
# incident_state_WV                        int32
# incident_city_Columbus                   int32
# incident_city_Northbend                  int32
# incident_city_Riverwood                  int32
# incident_city_Springfield                int32
# property_damage_NO                       int32
# property_damage_YES                      int32
# police_report_available_NO               int32
# police_report_available_YES              int32
# auto_make_Ford                           int32
# auto_make_Mercedes                       int32
# dtype: object
# int64

# %%
# Import statsmodels and add constant
import statsmodels.api as sm
X_train_selected_with_const = sm.add_constant(X_train_selected)

# Check the data
X_train_selected_with_const.head()
# Out:
#    const  log_vehicle_claim  policy_csl_250/500  policy_csl_500/1000  \
# 0    1.0           0.596724                   1                    0
# 1    1.0           0.621147                   0                    1
# 2    1.0          -1.695155                   1                    0
# 3    1.0           0.628584                   1                    0
# 4    1.0           0.725431                   0                    1
#
#    insured_relationship_not-in-family  insured_relationship_other-relative  \
# 0                                   1                                    0
# 1                                   1                                    0
# 2                                   0                                    0
# 3                                   0                                    0
# 4                                   0                                    0
#
#    insured_relationship_unmarried  insured_relationship_wife  \
# 0                               0                          0
# 1                               0                          0
# 2                               0                          0
# 3                               1                          0
# 4                               1                          0
#
#    collision_type_Front Collision  collision_type_Rear Collision  ...  \
# 0                               1                              0  ...
# 1                               0                              1  ...
# 2                               0                              0  ...
# 3                               0                              1  ...
# 4                               0                              0  ...
#
#    incident_city_Columbus  incident_city_Northbend  incident_city_Riverwood  \
# 0                       0                        0                        0
# 1                       0                        0                        0
# 2                       0                        0                        0
# 3                       0                        0                        0
# 4                       0                        1                        0
#
#    incident_city_Springfield  property_damage_NO  property_damage_YES  \
# 0                          0                   1                    0
# 1                          0                   0                    0
# 2                          1                   1                    0
# 3                          0                   1                    0
# 4                          0                   1                    0
#
#    police_report_available_NO  police_report_available_YES  auto_make_Ford  \
# 0                           1                            0               0
# 1                           0                            0               0
# 2                           1                            0               0
# 3                           1                            0               0
# 4                           0                            1               0
#
#    auto_make_Mercedes
# 0                   1
# 1                   0
# 2                   0
# 3                   0
# 4                   0
#
# [5 rows x 29 columns]

# %% [markdown]
# #### **7.2.2** Fit logistic regression model <font color="red">[2 Marks]</font>

# %%
# Fit a logistic Regression model on X_train after adding a constant and output the summary
X_train_selected_with_const = X_train_selected_with_const.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)

logit_model = sm.Logit(y_train, X_train_selected_with_const)
logit_result = logit_model.fit()


print(logit_result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.396630
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         fraud_reported   No. Observations:                  331
# Model:                          Logit   Df Residuals:                      302
# Method:                           MLE   Df Model:                           28
# Date:                Tue, 06 May 2025   Pseudo R-squ.:                  0.2736
# Time:                        20:40:13   Log-Likelihood:                -131.28
# converged:                       True   LL-Null:                       -180.73
# Covariance Type:            nonrobust   LLR p-value:                 7.653e-10
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# const                                  -1.6662      1.511     -1.103      0.270      -4.627       1.294
# log_vehicle_claim                       0.4556      0.666      0.684      0.494      -0.849       1.760
# policy_csl_250/500                      0.2123      0.383      0.555      0.579      -0.538       0.962
# policy_csl_500/1000                     0.5706      0.411      1.388      0.165      -0.235       1.377
# insured_relationship_not-in-family      0.1785      0.486      0.367      0.714      -0.775       1.132
# insured_relationship_other-relative     0.7623      0.469      1.624      0.104      -0.158       1.682
# insured_relationship_unmarried          1.1184      0.495      2.258      0.024       0.147       2.089
# insured_relationship_wife               0.9337      0.559      1.672      0.095      -0.161       2.028
# collision_type_Front Collision          1.7203      1.820      0.945      0.345      -1.848       5.288
# collision_type_Rear Collision           2.0268      1.733      1.169      0.242      -1.371       5.424
# collision_type_Side Collision           1.2895      1.733      0.744      0.457      -2.107       4.686
# incident_severity_Minor Damage         -2.2449      0.428     -5.239      0.000      -3.085      -1.405
# incident_severity_Total Loss           -2.2802      0.431     -5.290      0.000      -3.125      -1.435
# authorities_contacted_Fire             -0.2246      0.507     -0.443      0.658      -1.219       0.770
# authorities_contacted_Other             0.4174      0.498      0.839      0.401      -0.558       1.393
# authorities_contacted_Police            0.2569      0.459      0.560      0.575      -0.642       1.156
# incident_state_NY                      -1.0426      0.460     -2.268      0.023      -1.943      -0.142
# incident_state_SC                      -0.1158      0.412     -0.281      0.779      -0.923       0.692
# incident_state_WV                      -0.8809      0.514     -1.714      0.087      -1.888       0.127
# incident_city_Columbus                 -0.3931      0.510     -0.771      0.441      -1.392       0.606
# incident_city_Northbend                -0.4723      0.457     -1.034      0.301      -1.367       0.423
# incident_city_Riverwood                -0.0546      0.487     -0.112      0.911      -1.009       0.900
# incident_city_Springfield              -0.5151      0.532     -0.969      0.333      -1.558       0.527
# property_damage_NO                     -0.6544      0.396     -1.651      0.099      -1.431       0.123
# property_damage_YES                    -0.2671      0.398     -0.670      0.503      -1.048       0.514
# police_report_available_NO              0.4324      0.380      1.138      0.255      -0.312       1.177
# police_report_available_YES            -0.3864      0.430     -0.898      0.369      -1.230       0.457
# auto_make_Ford                          0.9885      0.565      1.748      0.080      -0.120       2.097
# auto_make_Mercedes                      0.9487      0.629      1.509      0.131      -0.284       2.181
# =======================================================================================================

# %% [markdown]
# **Model Interpretation**
#
# The output summary table will provide the features used for building model along with coefficient of each of the feature and their p-value. The p-value in a logistic regression model is used to assess the statistical significance of each coefficient. Lesser the p-value, more significant the feature is in the model.
#
# A positive coefficient will indicate that an increase in the value of feature would increase the odds of the event occurring. On the other hand, a negative coefficient means the opposite, i.e, an increase in the value of feature would decrease the odds of the event occurring.

# %% [markdown]
# Now check VIFs for presence of multicollinearity in the model.

# %% [markdown]
# #### **7.2.3** Evaluate VIF of features to assess multicollinearity <font color="red">[2 Marks]</font>

# %%
# Import 'variance_inflation_factor'
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Make a VIF DataFrame for all the variables present
vif_data = pd.DataFrame()
vif_data["feature"] = X_train_selected_with_const.columns
vif_data["VIF"] = [variance_inflation_factor(X_train_selected_with_const.values, i) for i in range(X_train_selected_with_const.shape[1])]


print(vif_data)
# Out:
#                                 feature        VIF
# 0                                 const  69.566356
# 1                     log_vehicle_claim  13.792337
# 2                    policy_csl_250/500   1.392226
# 3                   policy_csl_500/1000   1.457725
# 4    insured_relationship_not-in-family   1.308258
# 5   insured_relationship_other-relative   1.393616
# 6        insured_relationship_unmarried   1.278336
# 7             insured_relationship_wife   1.277173
# 8        collision_type_Front Collision  15.498072
# 9         collision_type_Rear Collision  19.197976
# 10        collision_type_Side Collision  18.268946
# 11       incident_severity_Minor Damage   1.363464
# 12         incident_severity_Total Loss   1.462363
# 13           authorities_contacted_Fire   1.760876
# 14          authorities_contacted_Other   1.637703
# 15         authorities_contacted_Police   1.581578
# 16                    incident_state_NY   1.612650
# 17                    incident_state_SC   1.488002
# 18                    incident_state_WV   1.443963
# 19               incident_city_Columbus   1.280845
# 20              incident_city_Northbend   1.234612
# 21              incident_city_Riverwood   1.251408
# 22            incident_city_Springfield   1.219598
# 23                   property_damage_NO   1.435174
# 24                  property_damage_YES   1.401899
# 25           police_report_available_NO   1.363204
# 26          police_report_available_YES   1.316319
# 27                       auto_make_Ford   1.073301
# 28                   auto_make_Mercedes   1.095583

# %% [markdown]
# Proceed to the next step if p-values and VIFs are within acceptable ranges. If you observe high p-values or VIFs, drop the features and retrain the model. <font color="red">[THIS IS OPTIONAL]</font>

# %% [markdown]
# #### **7.2.4** Make predictions on training data <font color = "red">[1 Mark]</font>

# %%
# Predict the probabilities on the training data
y_train_pred_prob = logit_result.predict(X_train_selected_with_const)

# Reshape it into an array
y_train_pred_prob = y_train_pred_prob.values

# %% [markdown]
# #### **7.2.5** Create a DataFrame that includes actual fraud reported flags, predicted probabilities, and a column indicating predicted classifications based on a cutoff value of 0.5 <font color="red">[1 Mark]</font>

# %%
# Create a new DataFrame containing the actual fraud reported flag and the probabilities predicted by the model
results_df = pd.DataFrame({"Actual": y_train, "Predicted_Prob": y_train_pred_prob})
print(results_df.head())


# Create new column indicating predicted classifications based on a cutoff value of 0.5
results_df["Predicted_Class"] = (results_df["Predicted_Prob"] >= 0.5).astype(int)
print(results_df.head())
# Out:
#    Actual  Predicted_Prob
# 0       0        0.543954
# 1       1        0.625232
# 2       0        0.020952
# 3       1        0.804596
# 4       0        0.058728
#    Actual  Predicted_Prob  Predicted_Class
# 0       0        0.543954                1
# 1       1        0.625232                1
# 2       0        0.020952                0
# 3       1        0.804596                1
# 4       0        0.058728                0

# %% [markdown]
# **Model performance evaluation**
#
# Evaluate the performance of the model based on predictions made on the training data.

# %% [markdown]
# #### **7.2.6** Check the accuracy of the model <font color = "red">[1 Mark]</font>

# %%
# Import metrics from sklearn for evaluation
from sklearn import metrics

# Check the accuracy of the model
accuracy = metrics.accuracy_score(y_train, results_df["Predicted_Class"])
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.8218

# %% [markdown]
# #### **7.2.7** Create a confusion matrix based on the predictions made on the training data <font color="red">[1 Mark]</font>

# %%
# Create confusion matrix
conf_matrix = metrics.confusion_matrix(y_train, results_df["Predicted_Class"])
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Confusion Matrix:
#  [[234  19]
#  [ 40  38]]

# %% [markdown]
# #### **7.2.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = conf_matrix.ravel()
print(f"True Negative: {tn}, False Positive: {fp}, False Negative: {fn}, True Positive: {tp}")
# Out:
# True Negative: 234, False Positive: 19, False Negative: 40, True Positive: 38

# %% [markdown]
# #### **7.2.9** Calculate sensitivity, specificity, precision, recall and F1-score <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity = tp / (tp + fn)
print(f"Sensitivity: {sensitivity:.4f}")

# Calculate the specificity
specificity = tn / (tn + fp)
print(f"Specificity: {specificity:.4f}")

# Calculate Precision
precision = tp / (tp + fp)
print(f"Precision: {precision:.4f}")

# Calculate Recall
recall = sensitivity
print(f"Recall: {recall:.4f}")

# Calculate F1 Score
f1_score = metrics.f1_score(y_train, results_df["Predicted_Class"])
print(f"F1 Score: {f1_score:.4f}")
# Out:
# Sensitivity: 0.4872
# Specificity: 0.9249
# Precision: 0.6667
# Recall: 0.4872
# F1 Score: 0.5630

# %% [markdown]
# ### **7.3 Find the Optimal Cutoff** <font color = red>[12 marks]</font>
# Find the optimal cutoff to improve model performance by evaluating various cutoff values and their impact on relevant metrics.

# %% [markdown]
# #### **7.3.1** Plot ROC Curve  to visualise the trade-off between true positive rate and false positive rate across different classification thresholds <font color="red">[2 Marks]</font>

# %%
# Import libraries or function to plot the ROC curve
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Define ROC function
def plot_roc_curve(fpr, tpr, roc_auc):
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC)')
    plt.legend(loc="lower right")
    plt.show()

# %%
# Call the ROC function
fpr, tpr, thresholds = roc_curve(y_train, y_train_pred_prob)
roc_auc = auc(fpr, tpr)
plot_roc_curve(fpr, tpr, roc_auc)

# %% [markdown]
# **Sensitivity and Specificity tradeoff**
#
# After analysing the area under the curve of the ROC, check the sensitivity and specificity tradeoff to find the optimal cutoff point.

# %% [markdown]
# #### **7.3.2** Predict on training data at various probability cutoffs <font color="red">[1 Mark]</font>

# %%
# Create columns with different probability cutoffs to explore the impact of cutoff on model performance
thresholds_array = [i/100 for i in range(0, 101)]

metrics_list = []

for threshold in thresholds_array:
    y_pred_cutoff = (y_train_pred_prob >= threshold).astype(int)

    # Calculate confusion matrix
    tn, fp, fn, tp = metrics.confusion_matrix(y_train, y_pred_cutoff).ravel()

    # Calculate sensitivity, specificity, and accuracy for this threshold
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    accuracy = metrics.accuracy_score(y_train, y_pred_cutoff)

    # Append results to list
    metrics_list.append([threshold, accuracy, sensitivity, specificity])

# %% [markdown]
# #### **7.3.3** Plot accuracy, sensitivity, specificity at different values of probability cutoffs <font color="red">[2 Marks]</font>

# %%
# Create a DataFrame to see the values of accuracy, sensitivity, and specificity at different values of probability cutoffs
metrics_df = pd.DataFrame(metrics_list, columns=["Threshold", "Accuracy", "Sensitivity", "Specificity"])

print(metrics_df.head())
# Out:
#    Threshold  Accuracy  Sensitivity  Specificity
# 0       0.00  0.235650     1.000000     0.000000
# 1       0.01  0.265861     0.987179     0.043478
# 2       0.02  0.320242     0.987179     0.114625
# 3       0.03  0.338369     0.961538     0.146245
# 4       0.04  0.383686     0.961538     0.205534

# %%
# Plot accuracy, sensitivity, and specificity at different values of probability cutoffs
plt.figure(figsize=(10, 6))
plt.plot(metrics_df["Threshold"], metrics_df["Accuracy"], label="Accuracy", color="blue")
plt.plot(metrics_df["Threshold"], metrics_df["Sensitivity"], label="Sensitivity", color="green")
plt.plot(metrics_df["Threshold"], metrics_df["Specificity"], label="Specificity", color="red")
plt.xlabel("Probability Threshold")
plt.ylabel("Metric Value")
plt.title("Accuracy, Sensitivity, and Specificity at Different Thresholds")
plt.legend(loc="lower left")
plt.show()

# %% [markdown]
# #### **7.3.4** Create a column for final prediction based on optimal cutoff <font color="red">[1 Mark]</font>

# %%
# Create a column for final prediction based on the optimal cutoff
optimal_cutoff = 0.5

# Create final prediction based on the optimal cutoff
results_df["Final_Prediction"] = (results_df["Predicted_Prob"] >= optimal_cutoff).astype(int)

# Check the final predictions
print(results_df.head())
# Out:
#    Actual  Predicted_Prob  Predicted_Class  Final_Prediction
# 0       0        0.543954                1                 1
# 1       1        0.625232                1                 1
# 2       0        0.020952                0                 0
# 3       1        0.804596                1                 1
# 4       0        0.058728                0                 0

# %% [markdown]
# #### **7.3.5** Calculate the accuracy <font color="red">[1 Mark]</font>

# %%
# Check the accuracy now
final_accuracy = metrics.accuracy_score(y_train, results_df["Final_Prediction"])

print(f"Final Accuracy: {final_accuracy:.4f}")
# Out:
# Final Accuracy: 0.8218

# %% [markdown]
# #### **7.3.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix once again
final_conf_matrix = metrics.confusion_matrix(y_train, results_df["Final_Prediction"])

print("Final Confusion Matrix:\n", final_conf_matrix)
# Out:
# Final Confusion Matrix:
#  [[234  19]
#  [ 40  38]]

# %% [markdown]
# #### **7.3.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = final_conf_matrix.ravel()

print(f"True Negative: {tn}, False Positive: {fp}, False Negative: {fn}, True Positive: {tp}")
# Out:
# True Negative: 234, False Positive: 19, False Negative: 40, True Positive: 38

# %% [markdown]
# #### **7.3.8** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Mark]</font>

# %%
# Calculate the sensitivity
final_sensitivity = tp / (tp + fn)
print(f"Final Sensitivity: {final_sensitivity:.4f}")

# Calculate the specificity
final_specificity = tn / (tn + fp)
print(f"Final Specificity: {final_specificity:.4f}")

# Calculate Precision
final_precision = tp / (tp + fp)
print(f"Final Precision: {final_precision:.4f}")

# Calculate Recall
final_recall = final_sensitivity
print(f"Final Recall: {final_recall:.4f}")

# Calculate F1 Score
final_f1_score = metrics.f1_score(y_train, results_df["Final_Prediction"])
print(f"Final F1 Score: {final_f1_score:.4f}")
# Out:
# Final Sensitivity: 0.4872
# Final Specificity: 0.9249
# Final Precision: 0.6667
# Final Recall: 0.4872
# Final F1 Score: 0.5630

# %% [markdown]
# **Precision and Recall tradeoff**
#
# Check optimal cutoff value by plotting precision-recall curve, and adjust the cutoff based on precision and recall tradeoff if required.

# %%
# Import precision-recall curve function
from sklearn.metrics import precision_recall_curve

# %% [markdown]
# #### **7.3.9** Plot precision-recall curve <font color="red">[1 Mark]</font>

# %%
# Plot precision-recall curve
from sklearn.metrics import precision_recall_curve

# Get precision, recall, and thresholds
precision, recall, pr_thresholds = precision_recall_curve(y_train, y_train_pred_prob)

# Plot the precision-recall curve
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, color='blue')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()

# %% [markdown]
# ### **7.4 Build Random Forest Model** <font color = red>[12 marks]</font>
# Now that we have built a logistic regression model, let's move on to building a random forest model.

# %% [markdown]
# #### **7.4.1** Import necessary libraries

# %%
# Import necessary libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_score, GridSearchCV

# %% [markdown]
# #### **7.4.2** Build the random forest model <font color="red">[1 Mark]</font>

# %%
# Build a base random forest model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# #### **7.4.3** Get feature importance scores and select important features <font color="red">[2 Marks]</font>

# %%
# Get feature importance scores from the trained model
feature_importances = rf_model.feature_importances_

# Create a DataFrame to visualise the importance scores
feature_importance_df = pd.DataFrame({
    'Feature': X_train_scaled.columns,
    'Importance': feature_importances
}).sort_values(by='Importance', ascending=False)

print(feature_importance_df)
# Out:
#                                 Feature  Importance
# 0                     log_vehicle_claim    0.136329
# 23       incident_severity_Minor Damage    0.049959
# 24         incident_severity_Total Loss    0.044241
# 40                   property_damage_NO    0.024916
# 42           police_report_available_NO    0.024365
# 31                    incident_state_SC    0.024152
# 2                   policy_csl_500/1000    0.023118
# 21        collision_type_Rear Collision    0.023070
# 1                    policy_csl_250/500    0.021712
# 29                    incident_state_NY    0.021349
# 27          authorities_contacted_Other    0.021084
# 43          police_report_available_YES    0.021081
# 26           authorities_contacted_Fire    0.019457
# 28         authorities_contacted_Police    0.019254
# 18       insured_relationship_unmarried    0.018768
# 16  insured_relationship_other-relative    0.018756
# 38              incident_city_Riverwood    0.018235
# 25     incident_severity_Trivial Damage    0.018202
# 34               incident_city_Columbus    0.018147
# 41                  property_damage_YES    0.017654
# 20       collision_type_Front Collision    0.017315
# 47                       auto_make_Ford    0.016989
# 22        collision_type_Side Collision    0.016476
# 50                   auto_make_Mercedes    0.016423
# 15   insured_relationship_not-in-family    0.015665
# 19            insured_relationship_wife    0.015560
# 36              incident_city_Northbend    0.015421
# 3          insured_hobbies_base-jumping    0.014634
# 33                    incident_state_WV    0.014396
# 44                        auto_make_BMW    0.014223
# 35              incident_city_Hillsdale    0.013719
# 54                     auto_make_Suburu    0.012667
# 32                    incident_state_VA    0.012502
# 17       insured_relationship_own-child    0.012416
# 45                  auto_make_Chevrolet    0.011817
# 48                      auto_make_Honda    0.011719
# 14             insured_hobbies_yachting    0.011610
# 46                      auto_make_Dodge    0.011510
# 56                 auto_make_Volkswagen    0.011321
# 39            incident_city_Springfield    0.011299
# 37             incident_city_Northbrook    0.011259
# 5               insured_hobbies_camping    0.009980
# 53                       auto_make_Saab    0.009933
# 12              insured_hobbies_reading    0.009873
# 4        insured_hobbies_bungie-jumping    0.009763
# 30                 incident_state_Other    0.009411
# 51                     auto_make_Nissan    0.009138
# 10            insured_hobbies_paintball    0.008777
# 49                       auto_make_Jeep    0.007844
# 6              insured_hobbies_exercise    0.007692
# 8                insured_hobbies_hiking    0.007610
# 55                     auto_make_Toyota    0.007003
# 7                  insured_hobbies_golf    0.006579
# 52                      auto_make_Other    0.006551
# 11                 insured_hobbies_polo    0.006411
# 13             insured_hobbies_sleeping    0.006227
# 9                insured_hobbies_movies    0.004420

# %%
# Select features with high importance scores
threshold = 0.01
important_features = feature_importance_df[feature_importance_df['Importance'] > threshold]['Feature'].tolist()

# Create a new training data with only the selected features
X_train_selected = X_train_scaled[important_features]

# %% [markdown]
# #### **7.4.4** Train the model with selected features <font color="red">[1 Mark]</font>

# %%
# Fit the model on the training data with selected features
rf_model_selected = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model_selected.fit(X_train_selected, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# #### **7.4.5** Generate predictions on the training data <font color="red">[1 Mark]</font>

# %%
# Generate predictions on training data
y_train_pred = rf_model_selected.predict(X_train_selected)

# %% [markdown]
# #### **7.4.6** Check accuracy of the model <font color="red">[1 Mark]</font>

# %%
# Check accuracy of the model
accuracy = accuracy_score(y_train, y_train_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 1.0

# %% [markdown]
# #### **7.4.7** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix to visualise the performance
conf_matrix = confusion_matrix(y_train, y_train_pred)


plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['No Fraud', 'Fraud'], yticklabels=['No Fraud', 'Fraud'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# #### **7.4.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = conf_matrix.ravel()

print(f'True Negative: {tn}, False Positive: {fp}, False Negative: {fn}, True Positive: {tp}')
# Out:
# True Negative: 253, False Positive: 0, False Negative: 0, True Positive: 78

# %% [markdown]
# #### **7.4.9** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate Sensitivity (Recall)
sensitivity = tp / (tp + fn)
print(f'Sensitivity (Recall): {sensitivity}')

# Calculate Specificity
specificity = tn / (tn + fp)
print(f'Specificity: {specificity}')

# Calculate Precision
precision = tp / (tp + fp)
print(f'Precision: {precision}')

# Calculate Recall (same as Sensitivity)
recall = sensitivity
print(f'Recall: {recall}')

# Calculate F1 Score
from sklearn.metrics import f1_score
f1 = f1_score(y_train, y_train_pred)
print(f'F1 Score: {f1}')
# Out:
# Sensitivity (Recall): 1.0
# Specificity: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0

# %% [markdown]
# #### **7.4.10** Check if the model is overfitting training data using cross validation <font color = "red">[2 marks]</font>

# %%
# Use cross validation to check if the model is overfitting
cv_scores = cross_val_score(rf_model_selected, X_train_selected, y_train, cv=5)

print(f'Cross-validation scores: {cv_scores}')
print(f'Mean cross-validation score: {cv_scores.mean()}')
# Out:
# Cross-validation scores: [0.76119403 0.78787879 0.81818182 0.78787879 0.75757576]
# Mean cross-validation score: 0.7825418362731795

# %% [markdown]
# ### **7.5 Hyperparameter Tuning** <font color = red>[10 Marks]</font>
#  Enhance the performance of the random forest model by systematically exploring and selecting optimal hyperparameter values using grid search.

# %% [markdown]
# #### **7.5.1** Use grid search to find the best hyperparameter values <font color = red>[2 Marks]</font>

# %%
# Use grid search to find the best hyperparamter values
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'bootstrap': [True, False]
}

# Initialize the grid search with cross-validation
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)

# Fit the grid search to the data
grid_search.fit(X_train_scaled, y_train)


# Best Hyperparameters
print(f'Best Hyperparameters: {grid_search.best_params_}')
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# Best Hyperparameters: {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}

# %% [markdown]
# #### **7.5.2** Build a random forest model based on hyperparameter tuning results <font color = red>[1 Mark]</font>

# %%
# Building random forest model based on results of hyperparameter tuning
best_rf_model = grid_search.best_estimator_
best_rf_model.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(bootstrap=False, n_estimators=50, random_state=42)

# %% [markdown]
# #### **7.5.3** Make predictions on training data <font color = red>[1 Mark]</font>

# %%
# Make predictions on training data
y_train_pred_best = best_rf_model.predict(X_train_scaled)

# %% [markdown]
# #### **7.5.4** Check accuracy of Random Forest Model <font color = red>[1 Mark]</font>

# %%
# Check the accuracy
accuracy_best = accuracy_score(y_train, y_train_pred_best)
print(f'Accuracy with Best Hyperparameters: {accuracy_best}')
# Out:
# Accuracy with Best Hyperparameters: 1.0

# %% [markdown]
# #### **7.5.5** Create confusion matrix <font color = red>[1 Mark]</font>

# %%
# Create the confusion matrix
conf_matrix_best = confusion_matrix(y_train, y_train_pred_best)

plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix_best, annot=True, fmt='d', cmap='Blues', xticklabels=['No Fraud', 'Fraud'], yticklabels=['No Fraud', 'Fraud'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix (Best Model)')
plt.show()

# %% [markdown]
# #### **7.5.6** Create variables for true positive, true negative, false positive and false negative <font color = red>[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn_best, fp_best, fn_best, tp_best = conf_matrix_best.ravel()

print(f'True Negative: {tn_best}, False Positive: {fp_best}, False Negative: {fn_best}, True Positive: {tp_best}')
# Out:
# True Negative: 253, False Positive: 0, False Negative: 0, True Positive: 78

# %% [markdown]
# #### **7.5.7** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color = red>[3 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity_best = tp_best / (tp_best + fn_best)
print(f'Sensitivity (Recall) - Best Model: {sensitivity_best}')

# Calculate the specificity
specificity_best = tn_best / (tn_best + fp_best)
print(f'Specificity - Best Model: {specificity_best}')

# Calculate Precision
precision_best = tp_best / (tp_best + fp_best)
print(f'Precision - Best Model: {precision_best}')

# Calculate Recall
recall_best = sensitivity_best
print(f'Recall - Best Model: {recall_best}')

# Calculate F1-Score
f1_best = f1_score(y_train, y_train_pred_best)
print(f'F1 Score - Best Model: {f1_best}')
# Out:
# Sensitivity (Recall) - Best Model: 1.0
# Specificity - Best Model: 1.0
# Precision - Best Model: 1.0
# Recall - Best Model: 1.0
# F1 Score - Best Model: 1.0

# %% [markdown]
# ## **8. Prediction and Model Evaluation** <font color = red>[20 marks]</font>
# Use the model from the previous step to make predictions on the validation data with the optimal cutoff. Then evaluate the model's performance using metrics such as accuracy, sensitivity, specificity, precision, and recall.

# %% [markdown]
# ### **8.1 Make predictions over validation data using logistic regression model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.1.1** Select relevant features for validation data and add constant <font color="red">[1 Mark]</font>

# %%
# Select the relevant features for validation data
X_val_selected = X_val_scaled[col]

# Add constant to X_validation
X_val_with_const = sm.add_constant(X_val_selected)

# %% [markdown]
# #### **8.1.2** Make predictions over validation data <font color="red">[1 Mark]</font>

# %%
# Make predictions on the validation data and store it in the variable 'y_validation_pred'
y_val_pred_proba = logit_result.predict(X_val_with_const)

# %% [markdown]
# #### **8.1.3** Create DataFrame with actual values and predicted values for validation data <font color="red">[2 Marks]</font>

# %%
#  Create DataFrame with actual values and predicted values for validation data
val_results = pd.DataFrame({
    'Actual': y_val.values,
    'Predicted_Prob': y_val_pred_proba
})

# %% [markdown]
# #### **8.1.4** Make final prediction based on cutoff value <font color="red">[1 Mark]</font>

# %%
# Make final predictions on the validation data using the optimal cutoff
optimal_cutoff = 0.5
val_results['Predicted'] = (val_results['Predicted_Prob'] >= optimal_cutoff).astype(int)

# %% [markdown]
# #### **8.1.5** Check the accuracy of logistic regression model on validation data <font color="red">[1 Mark]</font>

# %%
# Check the accuracy
accuracy = accuracy_score(val_results['Actual'], val_results['Predicted'])
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.8042

# %% [markdown]
# #### **8.1.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix
cm = confusion_matrix(val_results['Actual'], val_results['Predicted'])
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[97 12]
#  [16 18]]

# %% [markdown]
# #### **8.1.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = cm.ravel()
print(f"TP: {tp}, TN: {tn}, FP: {fp}, FN: {fn}")
# Out:
# TP: 18, TN: 97, FP: 12, FN: 16

# %% [markdown]
# #### **8.1.8** Calculate sensitivity, specificity, precision, recall and f1 score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
sensitivity = tp / (tp + fn)
print(f"Sensitivity (Recall for 1): {sensitivity:.4f}")

# Calculate the specificity
specificity = tn / (tn + fp)
print(f"Specificity (Recall for 0): {specificity:.4f}")

# Calculate Precision
precision = precision_score(val_results['Actual'], val_results['Predicted'])
print(f"Precision: {precision:.4f}")

# Calculate Recall
recall = recall_score(val_results['Actual'], val_results['Predicted'])
print(f"Recall: {recall:.4f}")

# Calculate F1 Score
f1 = f1_score(val_results['Actual'], val_results['Predicted'])
print(f"F1 Score: {f1:.4f}")
# Out:
# Sensitivity (Recall for 1): 0.5294
# Specificity (Recall for 0): 0.8899
# Precision: 0.6000
# Recall: 0.5294
# F1 Score: 0.5625

# %% [markdown]
# ### **8.2 Make predictions over validation data using random forest model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.2.1** Select the important features and make predictions over validation data <font color="red">[2 Marks]</font>

# %%
# Select the relevant features for validation data
X_val_selected = X_val_scaled[important_features]

# Make predictions on the validation data
y_val_pred_rf = rf_model_selected.predict(X_val_selected)

# %% [markdown]
# #### **8.2.2** Check accuracy of random forest model <font color="red">[1 Mark]</font>

# %%
# Check accuracy
accuracy = accuracy_score(y_val, y_val_pred_rf)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.7692

# %% [markdown]
# #### **8.2.3** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix
conf_matrix = confusion_matrix(y_val, y_val_pred_rf)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[103   6]
#  [ 27   7]]

# %% [markdown]
# #### **8.2.4** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = conf_matrix.ravel()
print(f"True Positives: {tp}")
print(f"True Negatives: {tn}")
print(f"False Positives: {fp}")
print(f"False Negatives: {fn}")
# Out:
# True Positives: 7
# True Negatives: 103
# False Positives: 6
# False Negatives: 27

# %% [markdown]
# #### **8.2.5** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[5 Marks]</font>

# %%
# Calculate Sensitivity
sensitivity = tp / (tp + fn)
print(f"Sensitivity (Recall): {sensitivity:.4f}")

# Calculate Specificity
specificity = tn / (tn + fp)
print(f"Specificity: {specificity:.4f}")

# Calculate Precision
precision = precision_score(y_val, y_val_pred_rf)
print(f"Precision: {precision:.4f}")

# Calculate Recall
recall = recall_score(y_val, y_val_pred_rf)
print(f"Recall: {recall:.4f}")

# Calculate F1-score
f1 = f1_score(y_val, y_val_pred_rf)
print(f"F1 Score: {f1:.4f}")
# Out:
# Sensitivity (Recall): 0.2059
# Specificity: 0.9450
# Precision: 0.5385
# Recall: 0.2059
# F1 Score: 0.2979

# %% [markdown]
# ## **Evaluation and Conclusion**

# %% [markdown]
# ### Evaluation of Logistic Regression Model
# #### The Logistic Regression model, using an optimal cutoff of 0.5 , achieved the following performance metrics on the validation data:
# - Accuracy: 0.8042
# - Sensitivity (Recall for Class 1 0.5294
# - Specificity (Recall for Class 0 0.8899
# - Precision: 0.6000
# - Recall: 0.5294
# - F 1 Score: 0.5625|

# %% [markdown]
# #### The confusion matrix reveals:
#
# - True Positives (TP): 18 (Fraudulent cases correctly identified)
# - True Negatives (TN): 97 (Non fraudulent cases correctly identified)
# - False Positives (FP): 12 (Non fraudulent cases incorrectly predicted as fraudulent)
# - False Negatives (FN): 16 (Fraudulent cases incorrectly predicted as non fraudulent)

# %% [markdown]
# ### Evaluation of Random Forest Model
# #### The Random Forest model, using the selected important features, demonstrated the following performance on the validation data:
#
# - Accuracy: 0.7692
# - Sensitivity (Recall): 0.2059
# - Specificity: 0.9450
# - Precision: 0.5385
# - Recall: 0.2059
# - F 1 Score: 0.2979
#
# #### The confusion matrix reveals:
#
# - True Positives (TP): 7
# - True Negatives (TN): 103
# - False Positives (FP): 6
# - False Negatives (FN): 27

# %% [markdown]
# ### Conclusion

# %% [markdown]
# #### Comparing the performance of the two models on the validation data:
#
# - Accuracy: The Logistic Regression model (0.8042) slightly outperformed the Random Forest model (0.7692) in terms of
# overall accuracy.
#
# - Sensitivity (Recall): The Logistic Regression model (0.5294) showed a significantly higher ability to correctly identify
# fraudulent cases compared to the Random Forest model (0.2059).
#
# - Specificity: The Random Forest model (0.9450) was better at correctly identifying non fraudulent cases than the Logistic
# Regression model (0.8899).
#
# - Precision: The Logistic Regression model (0.6000) had a slightly higher precision, meaning that when it predicted a case as
# fraudulent, it was more likely to be correct than the Random Forest model (0.5385).
#
# - F1 Score: The Logistic Regression model (0.5625) achieved a higher F1 score, indicating a better balance between precision
# and recall compared to the Random Forest model (0.2979).
#
# ### In summary, based on these metrics on the validation data, the Logistic Regression model appears to be a better overall performer for this fraud detection task. It demonstrates a better balance between correctly identifying fraudulent cases (sensitivity/recall) and minimizing false positives (precision), leading to a higher F1 However, it's important to note the trade offs. The Random Forest model exhibited higher specificity, meaning it was better at avoiding false alarms (incorrectly flagging non fraudulent transactions). The choice of the "better" model might ultimately depend on the specific business context and the relative costs associated with false positives and false negatives . If minimizing false alarms is a higher priority, the Random Forest model might be considered despite its lower sensitivity. Conversely, if capturing as many fraudulent cases as possible is crucial, the Logistic Regression model seems more suitable.
